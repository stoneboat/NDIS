# %%
import os
import sys
import numpy as np

# Navigate to the parent directory of the project structure
project_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
src_dir = os.path.join(project_dir, 'src')
log_dir = os.path.join(project_dir, 'log')
fig_dir = os.path.join(project_dir, 'fig')

# Add the src directory to sys.path
sys.path.append(src_dir)


from Dataset.cancer_dataset_for_LS import main_generate_cancer_matrices_for_LS, load_cancer_dataset_matrices_for_LS
from analysis.commons import data_normalize_by_features, concatenate_B_b

from estimator.NDIS import BasicNDISEstimator
from analysis.monotonicity_certifier_left import f_value_p, fprime_p
import mpmath as mp

# %%
def check_fprime_vs_fd(
    p: float,
    s: float,
    d: int,
    r: float,
    eps: float,
    h: float = 1e-4,
    workers_f: int = 1,
    workers_fp: int = 1,
    dps: int = 80,
    tail_sigma: float = 12.0,
    chunks_per_piece: int = 2,
):
    """
    Compare analytic f'(p) (via fprime_p) with a central finite-difference
    approximation based on f(p) = delta_pq_ls_right(p, p+s, d, r, eps, ...).

    Parameters
    ----------
    p, s, d, r, eps : as usual.
    h : float
        Base step size for finite differences (will be shrunk if too close to boundaries).
    workers_f : int
        Number of workers for delta_pq_ls_right (f).
    workers_fp : int
        Number of workers for fprime_p.
    dps : int
        Precision for mpmath.
    tail_sigma : float
        Truncation bound used in both f and f'.
    sign_w, chunks_per_piece :
        Passed to delta_pq_ls_right.
    """
    mp.mp.dps = int(dps)

    if not (0 < s < 1):
        raise ValueError("Require 0 < s < 1.")
    if not (0 < p < 1 - s):
        raise ValueError("Require 0 < p < 1 - s.")
    if r < 1:
        raise ValueError("Require r >= 1.")
    if d < 2:
        raise ValueError("Require d >= 2.")
    if eps < 0:
        raise ValueError("Require eps >= 0.")

    # Choose a safe step h so that p±h stays in (0,1-s)
    base_h = mp.mpf(h)
    p_mp = mp.mpf(p)
    s_mp = mp.mpf(s)

    max_left = p_mp
    max_right = (1 - s_mp) - p_mp
    h_eff = min(base_h, max_left / 2, max_right / 2)
    if h_eff <= 0:
        raise ValueError("p is too close to the boundary to use symmetric finite differences.")

    p_plus = float(p_mp + h_eff)
    p_minus = float(p_mp - h_eff)

    # f(p+h), f(p-h)
    f_plus = f_value_p(
        p_plus,
        s,
        d,
        r,
        eps,
        workers=workers_f,
        dps=dps,
        tail_sigma=tail_sigma,
        chunks_per_piece=chunks_per_piece,
    )
    f_minus = f_value_p(
        p_minus,
        s,
        d,
        r,
        eps,
        workers=workers_f,
        dps=dps,
        tail_sigma=tail_sigma,
        chunks_per_piece=chunks_per_piece,
    )

    # central finite difference
    fd = (f_plus - f_minus) / (2 * float(h_eff))

    # analytic derivative
    fp = fprime_p(
        p=p,
        s=s,
        d=d,
        r=r,
        eps=eps,
        workers=workers_fp,
        dps=dps,
        tail_sigma=tail_sigma,
    )

    abs_diff = abs(fp - fd)
    rel_diff = abs_diff / max(1.0, abs(fp), abs(fd))

    print("=== Check f'(p) vs finite difference ===")
    print(f"p         = {p}")
    print(f"s         = {s}")
    print(f"d         = {d}")
    print(f"r         = {r}")
    print(f"eps       = {eps}")
    print(f"h_eff     = {float(h_eff):.6e}")
    print(f"f(p+h)    = {f_plus:.12e}")
    print(f"f(p-h)    = {f_minus:.12e}")
    print(f"fd approx = {fd:.12e}")
    print(f"fprime_p  = {fp:.12e}")
    print(f"|diff|    = {abs_diff:.3e}")
    print(f"rel diff  = {rel_diff:.3e}")

    return {
        "p": p,
        "s": s,
        "d": d,
        "r": r,
        "eps": eps,
        "h_eff": float(h_eff),
        "f_plus": f_plus,
        "f_minus": f_minus,
        "fd": fd,
        "fprime": fp,
        "abs_diff": abs_diff,
        "rel_diff": rel_diff,
    }

# %%
res = check_fprime_vs_fd(
        p=0.9,
        s=0.0000001,
        d=5,
        r=2.0,
        eps=0.5,
        h=1e-4,
        workers_f=1,
        workers_fp=1,
        dps=80,
        tail_sigma=12.0,
        chunks_per_piece=2,
    )
# Out:
# === Check f'(p) vs finite difference ===
# p         = 0.9
# s         = 1e-07
# d         = 5
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 4.535060562611e-01
# f(p-h)    = 4.531037440660e-01
# fd approx = 2.011560975378e+00
# fprime_p  = 2.011560577061e+00
# |diff|    = 3.983e-07
# rel diff  = 1.980e-07

# %%
def sweep_check_fprime_vs_fd(
    ps = None,
    ss = None,
    ds = None,
    rs = None,
    eps_list = None,
    h: float = 1e-4,
    workers_f: int = 1,
    workers_fp: int = 1,
    dps: int = 80,
    tail_sigma: float = 12.0,
    chunks_per_piece: int = 2,
    verbose: bool = True,
):
    """
    Sweep over a small grid of (p, s, d, r, eps) and compare fprime_p
    against finite differences of f(p) = delta_pq_ls_right(p, p+s, ...).

    Returns a summary dict with the worst absolute and relative differences.
    """

    if ss is None:
        ss = [0.05, 0.1, 0.3]        # residual shares
    if ds is None:
        ds = [3, 5, 10]              # dimensions
    if rs is None:
        rs = [1.0, 2.0, 5.0]         # regularization
    if eps_list is None:
        eps_list = [0.1, 0.5, 1.0]   # epsilons
    if ps is None:
        # p will be scaled to (0,1-s) inside the loop
        ps = [0.1, 0.3, 0.5, 0.8]    # fraction of (1-s)

    max_abs = 0.0
    max_rel = 0.0
    worst_case = None

    for s in ss:
        for d in ds:
            for r in rs:
                for eps in eps_list:
                    for alpha in ps:
                        # map alpha in (0,1) → p in (0,1-s)
                        p = alpha * (1.0 - s)
                        if not (0 < p < 1 - s):
                            continue

                        res = check_fprime_vs_fd(
                            p=p,
                            s=s,
                            d=d,
                            r=r,
                            eps=eps,
                            h=h,
                            workers_f=workers_f,
                            workers_fp=workers_fp,
                            dps=dps,
                            tail_sigma=tail_sigma,
                            chunks_per_piece=chunks_per_piece,
                        )

                        abs_diff = res["abs_diff"]
                        rel_diff = res["rel_diff"]

                        if verbose:
                            print(
                                f"[p={p:.3f}, s={s:.2f}, d={d}, r={r:.1f}, eps={eps:.2f}] "
                                f"|diff|={abs_diff:.3e}, rel={rel_diff:.3e}"
                            )

                        if abs_diff > max_abs or rel_diff > max_rel:
                            max_abs = abs_diff
                            max_rel = rel_diff
                            worst_case = res

    summary = {
        "max_abs_diff": max_abs,
        "max_rel_diff": max_rel,
        "worst_case": worst_case,
    }

    print("\n=== Sweep summary ===")
    print(f"max |diff|  = {max_abs:.3e}")
    print(f"max rel diff = {max_rel:.3e}")
    if worst_case is not None:
        wc = worst_case
        print(
            f"worst at p={wc['p']}, s={wc['s']}, d={wc['d']}, "
            f"r={wc['r']}, eps={wc['eps']}"
        )

    return summary

# %%
summary = sweep_check_fprime_vs_fd(
    h=1e-4,
    workers_f=1,
    workers_fp=1,
    dps=80,
    tail_sigma=12.0,
    verbose=True,
)
# Out:
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.049095759008e-02
# f(p-h)    = 1.044659872122e-02
# fd approx = 2.217943443065e-01
# fprime_p  = 2.217943704431e-01
# |diff|    = 2.614e-08
# rel diff  = 2.614e-08
# [p=0.095, s=0.05, d=3, r=1.0, eps=0.10] |diff|=2.614e-08, rel=2.614e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 6.291988107330e-02
# f(p-h)    = 6.285345032287e-02
# fd approx = 3.321537521508e-01
# fprime_p  = 3.321537513293e-01
# |diff|    = 8.215e-10
# rel diff  = 8.215e-10
# [p=0.285, s=0.05, d=3, r=1.0, eps=0.10] |diff|=8.215e-10, rel=8.215e-10
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.381925801315e-01
# f(p-h)    = 1.380986649566e-01
# fd approx = 4.695758747447e-01
# fprime_p  = 4.695758697818e-01
# |diff|    = 4.963e-09
# rel diff  = 4.963e-09
# [p=0.475, s=0.05, d=3, r=1.0, eps=0.10] |diff|=4.963e-09, rel=4.963e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.304826570438e-01
# f(p-h)    = 3.302782602994e-01
# fd approx = 1.021983722124e+00
# fprime_p  = 1.021983648998e+00
# |diff|    = 7.313e-08
# rel diff  = 7.155e-08
# [p=0.760, s=0.05, d=3, r=1.0, eps=0.10] |diff|=7.313e-08, rel=7.155e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.604588310041e-05
# f(p-h)    = 2.535973724991e-05
# fd approx = 3.430729252501e-03
# fprime_p  = 3.430695644643e-03
# |diff|    = 3.361e-08
# rel diff  = 3.361e-08
# [p=0.095, s=0.05, d=3, r=1.0, eps=0.50] |diff|=3.361e-08, rel=3.361e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.804745368786e-02
# f(p-h)    = 1.800699947699e-02
# fd approx = 2.022710543319e-01
# fprime_p  = 2.022710547827e-01
# |diff|    = 4.509e-10
# rel diff  = 4.509e-10
# [p=0.285, s=0.05, d=3, r=1.0, eps=0.50] |diff|=4.509e-10, rel=4.509e-10
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 7.730478727898e-02
# f(p-h)    = 7.721949491447e-02
# fd approx = 4.264618225687e-01
# fprime_p  = 4.264618183545e-01
# |diff|    = 4.214e-09
# rel diff  = 4.214e-09
# [p=0.475, s=0.05, d=3, r=1.0, eps=0.50] |diff|=4.214e-09, rel=4.214e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.729051507953e-01
# f(p-h)    = 2.726866738945e-01
# fd approx = 1.092384503953e+00
# fprime_p  = 1.092384427347e+00
# |diff|    = 7.661e-08
# rel diff  = 7.013e-08
# [p=0.760, s=0.05, d=3, r=1.0, eps=0.50] |diff|=7.661e-08, rel=7.013e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 5.325866841245e-09
# f(p-h)    = 4.999030368429e-09
# fd approx = 1.634182364081e-06
# fprime_p  = 1.634004186404e-06
# |diff|    = 1.782e-10
# rel diff  = 1.782e-10
# [p=0.095, s=0.05, d=3, r=1.0, eps=1.00] |diff|=1.782e-10, rel=1.782e-10
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 3.969321154643e-03
# f(p-h)    = 3.954401874202e-03
# fd approx = 7.459640220798e-02
# fprime_p  = 7.459639486399e-02
# |diff|    = 7.344e-09
# rel diff  = 7.344e-09
# [p=0.285, s=0.05, d=3, r=1.0, eps=1.00] |diff|=7.344e-09, rel=7.344e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 3.886469175323e-02
# f(p-h)    = 3.880209183621e-02
# fd approx = 3.129995851038e-01
# fprime_p  = 3.129995786426e-01
# |diff|    = 6.461e-09
# rel diff  = 6.461e-09
# [p=0.475, s=0.05, d=3, r=1.0, eps=1.00] |diff|=6.461e-09, rel=6.461e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 3
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.175766119894e-01
# f(p-h)    = 2.173559156695e-01
# fd approx = 1.103481599864e+00
# fprime_p  = 1.103481519056e+00
# |diff|    = 8.081e-08
# rel diff  = 7.323e-08
# [p=0.760, s=0.05, d=3, r=1.0, eps=1.00] |diff|=8.081e-08, rel=7.323e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.820486867024e-02
# f(p-h)    = 1.814503750382e-02
# fd approx = 2.991558321240e-01
# fprime_p  = 2.991558442284e-01
# |diff|    = 1.210e-08
# rel diff  = 1.210e-08
# [p=0.095, s=0.05, d=3, r=2.0, eps=0.10] |diff|=1.210e-08, rel=1.210e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 8.012237490223e-02
# f(p-h)    = 8.004869810843e-02
# fd approx = 3.683839690105e-01
# fprime_p  = 3.683839660715e-01
# |diff|    = 2.939e-09
# rel diff  = 2.939e-09
# [p=0.285, s=0.05, d=3, r=2.0, eps=0.10] |diff|=2.939e-09, rel=2.939e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.630595618547e-01
# f(p-h)    = 1.629556990158e-01
# fd approx = 5.193141944802e-01
# fprime_p  = 5.193141877173e-01
# |diff|    = 6.763e-09
# rel diff  = 6.763e-09
# [p=0.475, s=0.05, d=3, r=2.0, eps=0.10] |diff|=6.763e-09, rel=6.763e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.842434093617e-01
# f(p-h)    = 3.839960207063e-01
# fd approx = 1.236943277274e+00
# fprime_p  = 1.236943168393e+00
# |diff|    = 1.089e-07
# rel diff  = 8.802e-08
# [p=0.760, s=0.05, d=3, r=2.0, eps=0.10] |diff|=1.089e-07, rel=8.802e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.340136664919e-04
# f(p-h)    = 1.313667372694e-04
# fd approx = 1.323464611248e-02
# fprime_p  = 1.323459773147e-02
# |diff|    = 4.838e-08
# rel diff  = 4.838e-08
# [p=0.095, s=0.05, d=3, r=2.0, eps=0.50] |diff|=4.838e-08, rel=4.838e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.699955123112e-02
# f(p-h)    = 2.694684419824e-02
# fd approx = 2.635351644041e-01
# fprime_p  = 2.635351656235e-01
# |diff|    = 1.219e-09
# rel diff  = 1.219e-09
# [p=0.285, s=0.05, d=3, r=2.0, eps=0.50] |diff|=1.219e-09, rel=1.219e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 9.858840904915e-02
# f(p-h)    = 9.848870727857e-02
# fd approx = 4.985088528909e-01
# fprime_p  = 4.985088466180e-01
# |diff|    = 6.273e-09
# rel diff  = 6.273e-09
# [p=0.475, s=0.05, d=3, r=2.0, eps=0.50] |diff|=6.273e-09, rel=6.273e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 3.295508590056e-01
# f(p-h)    = 3.292834408364e-01
# fd approx = 1.337090846164e+00
# fprime_p  = 1.337090730567e+00
# |diff|    = 1.156e-07
# rel diff  = 8.645e-08
# [p=0.760, s=0.05, d=3, r=2.0, eps=0.50] |diff|=1.156e-07, rel=8.645e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 8.476753005614e-08
# f(p-h)    = 8.063787363037e-08
# fd approx = 2.064828212885e-05
# fprime_p  = 2.064700829560e-05
# |diff|    = 1.274e-09
# rel diff  = 1.274e-09
# [p=0.095, s=0.05, d=3, r=2.0, eps=1.00] |diff|=1.274e-09, rel=1.274e-09
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 6.899426018779e-03
# f(p-h)    = 6.876419535331e-03
# fd approx = 1.150324172401e-01
# fprime_p  = 1.150324113099e-01
# |diff|    = 5.930e-09
# rel diff  = 5.930e-09
# [p=0.285, s=0.05, d=3, r=2.0, eps=1.00] |diff|=5.930e-09, rel=5.930e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 5.359365031193e-02
# f(p-h)    = 5.351459805790e-02
# fd approx = 3.952612701607e-01
# fprime_p  = 3.952612624473e-01
# |diff|    = 7.713e-09
# rel diff  = 7.713e-09
# [p=0.475, s=0.05, d=3, r=2.0, eps=1.00] |diff|=7.713e-09, rel=7.713e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 3
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.737667344580e-01
# f(p-h)    = 2.734899156960e-01
# fd approx = 1.384093810121e+00
# fprime_p  = 1.384093686572e+00
# |diff|    = 1.235e-07
# rel diff  = 8.926e-08
# [p=0.760, s=0.05, d=3, r=2.0, eps=1.00] |diff|=1.235e-07, rel=8.926e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.713994814909e-02
# f(p-h)    = 3.704964238513e-02
# fd approx = 4.515288198334e-01
# fprime_p  = 4.515288035286e-01
# |diff|    = 1.630e-08
# rel diff  = 1.630e-08
# [p=0.095, s=0.05, d=3, r=5.0, eps=0.10] |diff|=1.630e-08, rel=1.630e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.220118388171e-01
# f(p-h)    = 1.219171230255e-01
# fd approx = 4.735789582690e-01
# fprime_p  = 4.735789520101e-01
# |diff|    = 6.259e-09
# rel diff  = 6.259e-09
# [p=0.285, s=0.05, d=3, r=5.0, eps=0.10] |diff|=6.259e-09, rel=6.259e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 2.264382540287e-01
# f(p-h)    = 2.263079623584e-01
# fd approx = 6.514583515911e-01
# fprime_p  = 6.514583410798e-01
# |diff|    = 1.051e-08
# rel diff  = 1.051e-08
# [p=0.475, s=0.05, d=3, r=5.0, eps=0.10] |diff|=1.051e-08, rel=1.051e-08
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 5.123622320520e-01
# f(p-h)    = 5.120349626082e-01
# fd approx = 1.636347219022e+00
# fprime_p  = 1.636347095759e+00
# |diff|    = 1.233e-07
# rel diff  = 7.533e-08
# [p=0.760, s=0.05, d=3, r=5.0, eps=0.10] |diff|=1.233e-07, rel=7.533e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.209994019841e-03
# f(p-h)    = 1.195227379330e-03
# fd approx = 7.383320255482e-02
# fprime_p  = 7.383318836521e-02
# |diff|    = 1.419e-08
# rel diff  = 1.419e-08
# [p=0.095, s=0.05, d=3, r=5.0, eps=0.50] |diff|=1.419e-08, rel=1.419e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 5.233358562477e-02
# f(p-h)    = 5.225081946678e-02
# fd approx = 4.138307899382e-01
# fprime_p  = 4.138307915404e-01
# |diff|    = 1.602e-09
# rel diff  = 1.602e-09
# [p=0.285, s=0.05, d=3, r=5.0, eps=0.50] |diff|=1.602e-09, rel=1.602e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.545928218299e-01
# f(p-h)    = 1.544571526061e-01
# fd approx = 6.783461187961e-01
# fprime_p  = 6.783461086102e-01
# |diff|    = 1.019e-08
# rel diff  = 1.019e-08
# [p=0.475, s=0.05, d=3, r=5.0, eps=0.50] |diff|=1.019e-08, rel=1.019e-08
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 4.643874771079e-01
# f(p-h)    = 4.640283976297e-01
# fd approx = 1.795397390914e+00
# fprime_p  = 1.795397258845e+00
# |diff|    = 1.321e-07
# rel diff  = 7.356e-08
# [p=0.760, s=0.05, d=3, r=5.0, eps=0.50] |diff|=1.321e-07, rel=7.356e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 4.720369258742e-06
# f(p-h)    = 4.569807826217e-06
# fd approx = 7.528071626263e-04
# fprime_p  = 7.527917393546e-04
# |diff|    = 1.542e-08
# rel diff  = 1.542e-08
# [p=0.095, s=0.05, d=3, r=5.0, eps=1.00] |diff|=1.542e-08, rel=1.542e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 1.714412098679e-02
# f(p-h)    = 1.709750434053e-02
# fd approx = 2.330832313364e-01
# fprime_p  = 2.330832290046e-01
# |diff|    = 2.332e-09
# rel diff  = 2.332e-09
# [p=0.285, s=0.05, d=3, r=5.0, eps=1.00] |diff|=2.332e-09, rel=2.332e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 9.530396034226e-02
# f(p-h)    = 9.518277391448e-02
# fd approx = 6.059321389065e-01
# fprime_p  = 6.059321286774e-01
# |diff|    = 1.023e-08
# rel diff  = 1.023e-08
# [p=0.475, s=0.05, d=3, r=5.0, eps=1.00] |diff|=1.023e-08, rel=1.023e-08
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 3
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 4.103020399513e-01
# f(p-h)    = 4.099162365364e-01
# fd approx = 1.929017074635e+00
# fprime_p  = 1.929016930270e+00
# |diff|    = 1.444e-07
# rel diff  = 7.484e-08
# [p=0.760, s=0.05, d=3, r=5.0, eps=1.00] |diff|=1.444e-07, rel=7.484e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.273226031945e-02
# f(p-h)    = 1.268880503305e-02
# fd approx = 2.172764319709e-01
# fprime_p  = 2.172764488755e-01
# |diff|    = 1.690e-08
# rel diff  = 1.690e-08
# [p=0.095, s=0.05, d=5, r=1.0, eps=0.10] |diff|=1.690e-08, rel=1.690e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 6.499461602059e-02
# f(p-h)    = 6.492794694291e-02
# fd approx = 3.333453883952e-01
# fprime_p  = 3.333453875747e-01
# |diff|    = 8.206e-10
# rel diff  = 8.206e-10
# [p=0.285, s=0.05, d=5, r=1.0, eps=0.10] |diff|=8.206e-10, rel=8.206e-10
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.407515113917e-01
# f(p-h)    = 1.406567318219e-01
# fd approx = 4.738978489374e-01
# fprime_p  = 4.738978437129e-01
# |diff|    = 5.225e-09
# rel diff  = 5.225e-09
# [p=0.475, s=0.05, d=5, r=1.0, eps=0.10] |diff|=5.225e-09, rel=5.225e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.369132617716e-01
# f(p-h)    = 3.367014276778e-01
# fd approx = 1.059170468947e+00
# fprime_p  = 1.059170384824e+00
# |diff|    = 8.412e-08
# rel diff  = 7.942e-08
# [p=0.760, s=0.05, d=5, r=1.0, eps=0.10] |diff|=8.412e-08, rel=7.942e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 3.437737092952e-05
# f(p-h)    = 3.352914663057e-05
# fd approx = 4.241121494757e-03
# fprime_p  = 4.241087167087e-03
# |diff|    = 3.433e-08
# rel diff  = 3.433e-08
# [p=0.095, s=0.05, d=5, r=1.0, eps=0.50] |diff|=3.433e-08, rel=3.433e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.856316012863e-02
# f(p-h)    = 1.852208521708e-02
# fd approx = 2.053745577747e-01
# fprime_p  = 2.053745581562e-01
# |diff|    = 3.815e-10
# rel diff  = 3.815e-10
# [p=0.285, s=0.05, d=5, r=1.0, eps=0.50] |diff|=3.815e-10, rel=3.815e-10
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 7.852362524327e-02
# f(p-h)    = 7.843738016578e-02
# fd approx = 4.312253874313e-01
# fprime_p  = 4.312253829741e-01
# |diff|    = 4.457e-09
# rel diff  = 4.457e-09
# [p=0.475, s=0.05, d=5, r=1.0, eps=0.50] |diff|=4.457e-09, rel=4.457e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.776378477013e-01
# f(p-h)    = 2.774128506740e-01
# fd approx = 1.124985136491e+00
# fprime_p  = 1.124985050016e+00
# |diff|    = 8.648e-08
# rel diff  = 7.687e-08
# [p=0.760, s=0.05, d=5, r=1.0, eps=0.50] |diff|=8.648e-08, rel=7.687e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 7.334342102802e-09
# f(p-h)    = 6.898912159568e-09
# fd approx = 2.177149716170e-06
# fprime_p  = 2.176930360645e-06
# |diff|    = 2.194e-10
# rel diff  = 2.194e-10
# [p=0.095, s=0.05, d=5, r=1.0, eps=1.00] |diff|=2.194e-10, rel=2.194e-10
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 4.079164998025e-03
# f(p-h)    = 4.063957016488e-03
# fd approx = 7.603990768442e-02
# fprime_p  = 7.603990035285e-02
# |diff|    = 7.332e-09
# rel diff  = 7.332e-09
# [p=0.285, s=0.05, d=5, r=1.0, eps=1.00] |diff|=7.332e-09, rel=7.332e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 3.943015494249e-02
# f(p-h)    = 3.936683795323e-02
# fd approx = 3.165849463002e-01
# fprime_p  = 3.165849396562e-01
# |diff|    = 6.644e-09
# rel diff  = 6.644e-09
# [p=0.475, s=0.05, d=5, r=1.0, eps=1.00] |diff|=6.644e-09, rel=6.644e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 5
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.210513198349e-01
# f(p-h)    = 2.208250427125e-01
# fd approx = 1.131385611984e+00
# fprime_p  = 1.131385522298e+00
# |diff|    = 8.969e-08
# rel diff  = 7.927e-08
# [p=0.760, s=0.05, d=5, r=1.0, eps=1.00] |diff|=8.969e-08, rel=7.927e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 2.064254805463e-02
# f(p-h)    = 2.058424813326e-02
# fd approx = 2.914996068762e-01
# fprime_p  = 2.914996182105e-01
# |diff|    = 1.133e-08
# rel diff  = 1.133e-08
# [p=0.095, s=0.05, d=5, r=2.0, eps=0.10] |diff|=1.133e-08, rel=1.133e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 8.206425048952e-02
# f(p-h)    = 8.199048071779e-02
# fd approx = 3.688488586336e-01
# fprime_p  = 3.688488558452e-01
# |diff|    = 2.788e-09
# rel diff  = 2.788e-09
# [p=0.285, s=0.05, d=5, r=2.0, eps=0.10] |diff|=2.788e-09, rel=2.788e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.653788529984e-01
# f(p-h)    = 1.652742575467e-01
# fd approx = 5.229772586214e-01
# fprime_p  = 5.229772516643e-01
# |diff|    = 6.957e-09
# rel diff  = 6.957e-09
# [p=0.475, s=0.05, d=5, r=2.0, eps=0.10] |diff|=6.957e-09, rel=6.957e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.896728538903e-01
# f(p-h)    = 3.894198754194e-01
# fd approx = 1.264892354382e+00
# fprime_p  = 1.264892239117e+00
# |diff|    = 1.153e-07
# rel diff  = 9.113e-08
# [p=0.760, s=0.05, d=5, r=2.0, eps=0.10] |diff|=1.153e-07, rel=9.113e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.653988209560e-04
# f(p-h)    = 1.623294927216e-04
# fd approx = 1.534664117181e-02
# fprime_p  = 1.534659545860e-02
# |diff|    = 4.571e-08
# rel diff  = 4.571e-08
# [p=0.095, s=0.05, d=5, r=2.0, eps=0.50] |diff|=4.571e-08, rel=4.571e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.762560905589e-02
# f(p-h)    = 2.757233072519e-02
# fd approx = 2.663916534773e-01
# fprime_p  = 2.663916545542e-01
# |diff|    = 1.077e-09
# rel diff  = 1.077e-09
# [p=0.285, s=0.05, d=5, r=2.0, eps=0.50] |diff|=1.077e-09, rel=1.077e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 9.984644185353e-02
# f(p-h)    = 9.974588230546e-02
# fd approx = 5.027977403273e-01
# fprime_p  = 5.027977338413e-01
# |diff|    = 6.486e-09
# rel diff  = 6.486e-09
# [p=0.475, s=0.05, d=5, r=2.0, eps=0.50] |diff|=6.486e-09, rel=6.486e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 3.338600871247e-01
# f(p-h)    = 3.335873048553e-01
# fd approx = 1.363911347207e+00
# fprime_p  = 1.363911225017e+00
# |diff|    = 1.222e-07
# rel diff  = 8.959e-08
# [p=0.760, s=0.05, d=5, r=2.0, eps=0.50] |diff|=1.222e-07, rel=8.959e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 1.101366848345e-07
# f(p-h)    = 1.049470928157e-07
# fd approx = 2.594796009411e-05
# fprime_p  = 2.594648353210e-05
# |diff|    = 1.477e-09
# rel diff  = 1.477e-09
# [p=0.095, s=0.05, d=5, r=2.0, eps=1.00] |diff|=1.477e-09, rel=1.477e-09
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 7.061973033343e-03
# f(p-h)    = 7.038610050597e-03
# fd approx = 1.168149137307e-01
# fprime_p  = 1.168149078295e-01
# |diff|    = 5.901e-09
# rel diff  = 5.901e-09
# [p=0.285, s=0.05, d=5, r=2.0, eps=1.00] |diff|=5.901e-09, rel=5.901e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 5.424694280883e-02
# f(p-h)    = 5.416716419879e-02
# fd approx = 3.988930501998e-01
# fprime_p  = 3.988930423075e-01
# |diff|    = 7.892e-09
# rel diff  = 7.892e-09
# [p=0.475, s=0.05, d=5, r=2.0, eps=1.00] |diff|=7.892e-09, rel=7.892e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 5
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.771610901790e-01
# f(p-h)    = 2.768792867978e-01
# fd approx = 1.409016905851e+00
# fprime_p  = 1.409016775615e+00
# |diff|    = 1.302e-07
# rel diff  = 9.243e-08
# [p=0.760, s=0.05, d=5, r=2.0, eps=1.00] |diff|=1.302e-07, rel=9.243e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.950202618448e-02
# f(p-h)    = 3.941350206258e-02
# fd approx = 4.426206095206e-01
# fprime_p  = 4.426205969913e-01
# |diff|    = 1.253e-08
# rel diff  = 1.253e-08
# [p=0.095, s=0.05, d=5, r=5.0, eps=0.10] |diff|=1.253e-08, rel=1.253e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.237423584252e-01
# f(p-h)    = 1.236477325393e-01
# fd approx = 4.731294296838e-01
# fprime_p  = 4.731294235677e-01
# |diff|    = 6.116e-09
# rel diff  = 6.116e-09
# [p=0.285, s=0.05, d=5, r=5.0, eps=0.10] |diff|=6.116e-09, rel=6.116e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 2.283605415671e-01
# f(p-h)    = 2.282297652748e-01
# fd approx = 6.538814614909e-01
# fprime_p  = 6.538814508854e-01
# |diff|    = 1.061e-08
# rel diff  = 1.061e-08
# [p=0.475, s=0.05, d=5, r=5.0, eps=0.10] |diff|=1.061e-08, rel=1.061e-08
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 5.161883428926e-01
# f(p-h)    = 5.158581243364e-01
# fd approx = 1.651092780553e+00
# fprime_p  = 1.651092656020e+00
# |diff|    = 1.245e-07
# rel diff  = 7.542e-08
# [p=0.760, s=0.05, d=5, r=5.0, eps=0.10] |diff|=1.245e-07, rel=7.542e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.366578274410e-03
# f(p-h)    = 1.350736447410e-03
# fd approx = 7.920913500066e-02
# fprime_p  = 7.920912618394e-02
# |diff|    = 8.817e-09
# rel diff  = 8.817e-09
# [p=0.095, s=0.05, d=5, r=5.0, eps=0.50] |diff|=8.817e-09, rel=8.817e-09
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 5.315555775782e-02
# f(p-h)    = 5.307233211190e-02
# fd approx = 4.161282295906e-01
# fprime_p  = 4.161282310088e-01
# |diff|    = 1.418e-09
# rel diff  = 1.418e-09
# [p=0.285, s=0.05, d=5, r=5.0, eps=0.50] |diff|=1.418e-09, rel=1.418e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.559067818558e-01
# f(p-h)    = 1.557704457011e-01
# fd approx = 6.816807737443e-01
# fprime_p  = 6.816807634068e-01
# |diff|    = 1.034e-08
# rel diff  = 1.034e-08
# [p=0.475, s=0.05, d=5, r=5.0, eps=0.50] |diff|=1.034e-08, rel=1.034e-08
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 4.678466208547e-01
# f(p-h)    = 4.674842833502e-01
# fd approx = 1.811687522387e+00
# fprime_p  = 1.811687388585e+00
# |diff|    = 1.338e-07
# rel diff  = 7.385e-08
# [p=0.760, s=0.05, d=5, r=5.0, eps=0.50] |diff|=1.338e-07, rel=7.385e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 5.610259641009e-06
# f(p-h)    = 5.436868340834e-06
# fd approx = 8.669565008782e-04
# fprime_p  = 8.669401043260e-04
# |diff|    = 1.640e-08
# rel diff  = 1.640e-08
# [p=0.095, s=0.05, d=5, r=5.0, eps=1.00] |diff|=1.640e-08, rel=1.640e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 1.743913016341e-02
# f(p-h)    = 1.739204506886e-02
# fd approx = 2.354254727548e-01
# fprime_p  = 2.354254704372e-01
# |diff|    = 2.318e-09
# rel diff  = 2.318e-09
# [p=0.285, s=0.05, d=5, r=5.0, eps=1.00] |diff|=2.318e-09, rel=2.318e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 9.613358802493e-02
# f(p-h)    = 9.601168883766e-02
# fd approx = 6.094959363694e-01
# fprime_p  = 6.094959259853e-01
# |diff|    = 1.038e-08
# rel diff  = 1.038e-08
# [p=0.475, s=0.05, d=5, r=5.0, eps=1.00] |diff|=1.038e-08, rel=1.038e-08
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 5
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 4.133834488026e-01
# f(p-h)    = 4.129941516665e-01
# fd approx = 1.946485680225e+00
# fprime_p  = 1.946485533600e+00
# |diff|    = 1.466e-07
# rel diff  = 7.533e-08
# [p=0.760, s=0.05, d=5, r=5.0, eps=1.00] |diff|=1.466e-07, rel=7.533e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.971067826062e-02
# f(p-h)    = 1.967157020937e-02
# fd approx = 1.955402562515e-01
# fprime_p  = 1.955402645656e-01
# |diff|    = 8.314e-09
# rel diff  = 8.314e-09
# [p=0.095, s=0.05, d=10, r=1.0, eps=0.10] |diff|=8.314e-09, rel=8.314e-09
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 7.077437097359e-02
# f(p-h)    = 7.070745599039e-02
# fd approx = 3.345749160068e-01
# fprime_p  = 3.345749153886e-01
# |diff|    = 6.183e-10
# rel diff  = 6.183e-10
# [p=0.285, s=0.05, d=10, r=1.0, eps=0.10] |diff|=6.183e-10, rel=6.183e-10
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.476306414699e-01
# f(p-h)    = 1.475336342198e-01
# fd approx = 4.850362505426e-01
# fprime_p  = 4.850362446122e-01
# |diff|    = 5.930e-09
# rel diff  = 5.930e-09
# [p=0.475, s=0.05, d=10, r=1.0, eps=0.10] |diff|=5.930e-09, rel=5.930e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.547591171900e-01
# f(p-h)    = 3.545247403902e-01
# fd approx = 1.171883999166e+00
# fprime_p  = 1.171883873768e+00
# |diff|    = 1.254e-07
# rel diff  = 1.070e-07
# [p=0.760, s=0.05, d=10, r=1.0, eps=0.10] |diff|=1.254e-07, rel=1.070e-07
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 6.769310575889e-05
# f(p-h)    = 6.629361602446e-05
# fd approx = 6.997448672142e-03
# fprime_p  = 6.997414844800e-03
# |diff|    = 3.383e-08
# rel diff  = 3.383e-08
# [p=0.095, s=0.05, d=10, r=1.0, eps=0.50] |diff|=3.383e-08, rel=3.383e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.992514987003e-02
# f(p-h)    = 1.988249381354e-02
# fd approx = 2.132802824582e-01
# fprime_p  = 2.132802826498e-01
# |diff|    = 1.916e-10
# rel diff  = 1.916e-10
# [p=0.285, s=0.05, d=10, r=1.0, eps=0.50] |diff|=1.916e-10, rel=1.916e-10
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 8.168828480697e-02
# f(p-h)    = 8.159957883695e-02
# fd approx = 4.435298500831e-01
# fprime_p  = 4.435298449761e-01
# |diff|    = 5.107e-09
# rel diff  = 5.107e-09
# [p=0.475, s=0.05, d=10, r=1.0, eps=0.50] |diff|=5.107e-09, rel=5.107e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.901795214515e-01
# f(p-h)    = 2.899365854155e-01
# fd approx = 1.214680179598e+00
# fprime_p  = 1.214680062943e+00
# |diff|    = 1.167e-07
# rel diff  = 9.604e-08
# [p=0.760, s=0.05, d=10, r=1.0, eps=0.50] |diff|=1.167e-07, rel=9.604e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 1.619523902074e-08
# f(p-h)    = 1.531364517782e-08
# fd approx = 4.407969214584e-06
# fprime_p  = 4.407608033380e-06
# |diff|    = 3.612e-10
# rel diff  = 3.612e-10
# [p=0.095, s=0.05, d=10, r=1.0, eps=1.00] |diff|=3.612e-10, rel=3.612e-10
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 4.367520567636e-03
# f(p-h)    = 4.351568967326e-03
# fd approx = 7.975800155016e-02
# fprime_p  = 7.975799424614e-02
# |diff|    = 7.304e-09
# rel diff  = 7.304e-09
# [p=0.285, s=0.05, d=10, r=1.0, eps=1.00] |diff|=7.304e-09, rel=7.304e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 4.088585974711e-02
# f(p-h)    = 4.082070485973e-02
# fd approx = 3.257744369356e-01
# fprime_p  = 3.257744298109e-01
# |diff|    = 7.125e-09
# rel diff  = 7.125e-09
# [p=0.475, s=0.05, d=10, r=1.0, eps=1.00] |diff|=7.125e-09, rel=7.125e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 10
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.301117056663e-01
# f(p-h)    = 2.298705520216e-01
# fd approx = 1.205768223360e+00
# fprime_p  = 1.205768108437e+00
# |diff|    = 1.149e-07
# rel diff  = 9.531e-08
# [p=0.760, s=0.05, d=10, r=1.0, eps=1.00] |diff|=1.149e-07, rel=9.531e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 2.734712210437e-02
# f(p-h)    = 2.729355244614e-02
# fd approx = 2.678482911825e-01
# fprime_p  = 2.678483033421e-01
# |diff|    = 1.216e-08
# rel diff  = 1.216e-08
# [p=0.095, s=0.05, d=10, r=2.0, eps=0.10] |diff|=1.216e-08, rel=1.216e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 8.723881736553e-02
# f(p-h)    = 8.716491192908e-02
# fd approx = 3.695271822561e-01
# fprime_p  = 3.695271798658e-01
# |diff|    = 2.390e-09
# rel diff  = 2.390e-09
# [p=0.285, s=0.05, d=10, r=2.0, eps=0.10] |diff|=2.390e-09, rel=2.390e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.714765341581e-01
# f(p-h)    = 1.713700514210e-01
# fd approx = 5.324136853667e-01
# fprime_p  = 5.324136778876e-01
# |diff|    = 7.479e-09
# rel diff  = 7.479e-09
# [p=0.475, s=0.05, d=10, r=2.0, eps=0.10] |diff|=7.479e-09, rel=7.479e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 4.041502424820e-01
# f(p-h)    = 4.038817704377e-01
# fd approx = 1.342360221341e+00
# fprime_p  = 1.342360086424e+00
# |diff|    = 1.349e-07
# rel diff  = 1.005e-07
# [p=0.760, s=0.05, d=10, r=2.0, eps=0.10] |diff|=1.349e-07, rel=1.005e-07
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.751924091121e-04
# f(p-h)    = 2.708601929726e-04
# fd approx = 2.166108069744e-02
# fprime_p  = 2.166104324525e-02
# |diff|    = 3.745e-08
# rel diff  = 3.745e-08
# [p=0.095, s=0.05, d=10, r=2.0, eps=0.50] |diff|=3.745e-08, rel=3.745e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.925607333271e-02
# f(p-h)    = 2.920135918901e-02
# fd approx = 2.735707184688e-01
# fprime_p  = 2.735707191860e-01
# |diff|    = 7.172e-10
# rel diff  = 7.172e-10
# [p=0.285, s=0.05, d=10, r=2.0, eps=0.50] |diff|=7.172e-10, rel=7.172e-10
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.030833166116e-01
# f(p-h)    = 1.029805584113e-01
# fd approx = 5.137910014966e-01
# fprime_p  = 5.137909944529e-01
# |diff|    = 7.044e-09
# rel diff  = 7.044e-09
# [p=0.475, s=0.05, d=10, r=2.0, eps=0.50] |diff|=7.044e-09, rel=7.044e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 3.450808328547e-01
# f(p-h)    = 3.447937788219e-01
# fd approx = 1.435270164145e+00
# fprime_p  = 1.435270023577e+00
# |diff|    = 1.406e-07
# rel diff  = 9.794e-08
# [p=0.760, s=0.05, d=10, r=2.0, eps=0.50] |diff|=1.406e-07, rel=9.794e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.099739798869e-07
# f(p-h)    = 2.009015746047e-07
# fd approx = 4.536202641122e-05
# fprime_p  = 4.535993354737e-05
# |diff|    = 2.093e-09
# rel diff  = 2.093e-09
# [p=0.095, s=0.05, d=10, r=2.0, eps=1.00] |diff|=2.093e-09, rel=2.093e-09
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 7.484860971793e-03
# f(p-h)    = 7.460588281148e-03
# fd approx = 1.213634532225e-01
# fprime_p  = 1.213634473853e-01
# |diff|    = 5.837e-09
# rel diff  = 5.837e-09
# [p=0.285, s=0.05, d=10, r=2.0, eps=1.00] |diff|=5.837e-09, rel=5.837e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 5.591864675757e-02
# f(p-h)    = 5.583701759027e-02
# fd approx = 4.081458364696e-01
# fprime_p  = 4.081458281129e-01
# |diff|    = 8.357e-09
# rel diff  = 8.357e-09
# [p=0.475, s=0.05, d=10, r=2.0, eps=1.00] |diff|=8.357e-09, rel=8.357e-09
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 10
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.859092993020e-01
# f(p-h)    = 2.856144779189e-01
# fd approx = 1.474106915433e+00
# fprime_p  = 1.474106767196e+00
# |diff|    = 1.482e-07
# rel diff  = 1.006e-07
# [p=0.760, s=0.05, d=10, r=2.0, eps=1.00] |diff|=1.482e-07, rel=1.006e-07
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 4.549506805312e-02
# f(p-h)    = 4.541089446773e-02
# fd approx = 4.208679269543e-01
# fprime_p  = 4.208679225249e-01
# |diff|    = 4.429e-09
# rel diff  = 4.429e-09
# [p=0.095, s=0.05, d=10, r=5.0, eps=0.10] |diff|=4.429e-09, rel=4.429e-09
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.281535981714e-01
# f(p-h)    = 1.280592002597e-01
# fd approx = 4.719895585324e-01
# fprime_p  = 4.719895527823e-01
# |diff|    = 5.750e-09
# rel diff  = 5.750e-09
# [p=0.285, s=0.05, d=10, r=5.0, eps=0.10] |diff|=5.750e-09, rel=5.750e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 2.332598844283e-01
# f(p-h)    = 2.331278742068e-01
# fd approx = 6.600511075354e-01
# fprime_p  = 6.600510966871e-01
# |diff|    = 1.085e-08
# rel diff  = 1.085e-08
# [p=0.475, s=0.05, d=10, r=5.0, eps=0.10] |diff|=1.085e-08, rel=1.085e-08
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 5.259355850850e-01
# f(p-h)    = 5.255979010445e-01
# fd approx = 1.688420202394e+00
# fprime_p  = 1.688420075120e+00
# |diff|    = 1.273e-07
# rel diff  = 7.538e-08
# [p=0.760, s=0.05, d=10, r=5.0, eps=0.10] |diff|=1.273e-07, rel=7.538e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.830208899073e-03
# f(p-h)    = 1.811594004838e-03
# fd approx = 9.307447117438e-02
# fprime_p  = 9.307447312697e-02
# |diff|    = 1.953e-09
# rel diff  = 1.953e-09
# [p=0.095, s=0.05, d=10, r=5.0, eps=0.50] |diff|=1.953e-09, rel=1.953e-09
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 5.525675973120e-02
# f(p-h)    = 5.517239992070e-02
# fd approx = 4.217990524977e-01
# fprime_p  = 4.217990534665e-01
# |diff|    = 9.688e-10
# rel diff  = 9.688e-10
# [p=0.285, s=0.05, d=10, r=5.0, eps=0.50] |diff|=9.688e-10, rel=9.688e-10
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.592400245353e-01
# f(p-h)    = 1.591020042441e-01
# fd approx = 6.901014556578e-01
# fprime_p  = 6.901014449370e-01
# |diff|    = 1.072e-08
# rel diff  = 1.072e-08
# [p=0.475, s=0.05, d=10, r=5.0, eps=0.50] |diff|=1.072e-08, rel=1.072e-08
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 4.766197578178e-01
# f(p-h)    = 4.762491781483e-01
# fd approx = 1.852898347948e+00
# fprime_p  = 1.852898210126e+00
# |diff|    = 1.378e-07
# rel diff  = 7.438e-08
# [p=0.760, s=0.05, d=10, r=5.0, eps=0.50] |diff|=1.378e-07, rel=7.438e-08
# === Check f'(p) vs finite difference ===
# p         = 0.095
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 8.563945868268e-06
# f(p-h)    = 8.319786926868e-06
# fd approx = 1.220794706998e-03
# fprime_p  = 1.220775887226e-03
# |diff|    = 1.882e-08
# rel diff  = 1.882e-08
# [p=0.095, s=0.05, d=10, r=5.0, eps=1.00] |diff|=1.882e-08, rel=1.882e-08
# === Check f'(p) vs finite difference ===
# p         = 0.285
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 1.819635265546e-02
# f(p-h)    = 1.814808744210e-02
# fd approx = 2.413260667799e-01
# fprime_p  = 2.413260644867e-01
# |diff|    = 2.293e-09
# rel diff  = 2.293e-09
# [p=0.285, s=0.05, d=10, r=5.0, eps=1.00] |diff|=2.293e-09, rel=2.293e-09
# === Check f'(p) vs finite difference ===
# p         = 0.475
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 9.823694060369e-02
# f(p-h)    = 9.811324410436e-02
# fd approx = 6.184824966383e-01
# fprime_p  = 6.184824858610e-01
# |diff|    = 1.078e-08
# rel diff  = 1.078e-08
# [p=0.475, s=0.05, d=10, r=5.0, eps=1.00] |diff|=1.078e-08, rel=1.078e-08
# === Check f'(p) vs finite difference ===
# p         = 0.76
# s         = 0.05
# d         = 10
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 4.211827822164e-01
# f(p-h)    = 4.207846553884e-01
# fd approx = 1.990634140177e+00
# fprime_p  = 1.990633988109e+00
# |diff|    = 1.521e-07
# rel diff  = 7.639e-08
# [p=0.760, s=0.05, d=10, r=5.0, eps=1.00] |diff|=1.521e-07, rel=7.639e-08
# === Check f'(p) vs finite difference ===
# p         = 0.09000000000000001
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.959249056867e-02
# f(p-h)    = 1.954185718371e-02
# fd approx = 2.531669248214e-01
# fprime_p  = 2.531669680026e-01
# |diff|    = 4.318e-08
# rel diff  = 4.318e-08
# [p=0.090, s=0.10, d=3, r=1.0, eps=0.10] |diff|=4.318e-08, rel=4.318e-08
# === Check f'(p) vs finite difference ===
# p         = 0.27
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 7.299995965454e-02
# f(p-h)    = 7.293264368653e-02
# fd approx = 3.365798400583e-01
# fprime_p  = 3.365798355173e-01
# |diff|    = 4.541e-09
# rel diff  = 4.541e-09
# [p=0.270, s=0.10, d=3, r=1.0, eps=0.10] |diff|=4.541e-09, rel=4.541e-09
# === Check f'(p) vs finite difference ===
# p         = 0.45
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.451584497692e-01
# f(p-h)    = 1.450626426615e-01
# fd approx = 4.790355385126e-01
# fprime_p  = 4.790355317802e-01
# |diff|    = 6.732e-09
# rel diff  = 6.732e-09
# [p=0.450, s=0.10, d=3, r=1.0, eps=0.10] |diff|=6.732e-09, rel=6.732e-09
# === Check f'(p) vs finite difference ===
# p         = 0.7200000000000001
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.400919744327e-01
# f(p-h)    = 3.398566670806e-01
# fd approx = 1.176536760545e+00
# fprime_p  = 1.176536617804e+00
# |diff|    = 1.427e-07
# rel diff  = 1.213e-07
# [p=0.720, s=0.10, d=3, r=1.0, eps=0.10] |diff|=1.427e-07, rel=1.213e-07
# === Check f'(p) vs finite difference ===
# p         = 0.09000000000000001
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 0.000000000000e+00
# f(p-h)    = 0.000000000000e+00
# fd approx = 0.000000000000e+00
# fprime_p  = 0.000000000000e+00
# |diff|    = 0.000e+00
# rel diff  = 0.000e+00
# [p=0.090, s=0.10, d=3, r=1.0, eps=0.50] |diff|=0.000e+00, rel=0.000e+00
# === Check f'(p) vs finite difference ===
# p         = 0.27
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.673658584995e-02
# f(p-h)    = 1.669284472782e-02
# fd approx = 2.187056106523e-01
# fprime_p  = 2.187056152490e-01
# |diff|    = 4.597e-09
# rel diff  = 4.597e-09
# [p=0.270, s=0.10, d=3, r=1.0, eps=0.50] |diff|=4.597e-09, rel=4.597e-09
# === Check f'(p) vs finite difference ===
# p         = 0.45
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 7.578932973771e-02
# f(p-h)    = 7.570108844828e-02
# fd approx = 4.412064471695e-01
# fprime_p  = 4.412064412841e-01
# |diff|    = 5.885e-09
# rel diff  = 5.885e-09
# [p=0.450, s=0.10, d=3, r=1.0, eps=0.50] |diff|=5.885e-09, rel=5.885e-09
# === Check f'(p) vs finite difference ===
# p         = 0.7200000000000001
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.717326130687e-01
# f(p-h)    = 2.714883140731e-01
# fd approx = 1.221494977915e+00
# fprime_p  = 1.221494833662e+00
# |diff|    = 1.443e-07
# rel diff  = 1.181e-07
# [p=0.720, s=0.10, d=3, r=1.0, eps=0.50] |diff|=1.443e-07, rel=1.181e-07
# === Check f'(p) vs finite difference ===
# p         = 0.09000000000000001
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 0.000000000000e+00
# f(p-h)    = 0.000000000000e+00
# fd approx = 0.000000000000e+00
# fprime_p  = 0.000000000000e+00
# |diff|    = 0.000e+00
# rel diff  = 0.000e+00
# [p=0.090, s=0.10, d=3, r=1.0, eps=1.00] |diff|=0.000e+00, rel=0.000e+00
# === Check f'(p) vs finite difference ===
# p         = 0.27
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.351325883529e-03
# f(p-h)    = 2.339254763538e-03
# fd approx = 6.035559995686e-02
# fprime_p  = 6.035558971828e-02
# |diff|    = 1.024e-08
# rel diff  = 1.024e-08
# [p=0.270, s=0.10, d=3, r=1.0, eps=1.00] |diff|=1.024e-08, rel=1.024e-08
# === Check f'(p) vs finite difference ===
# p         = 0.45
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 3.371925850009e-02
# f(p-h)    = 3.365782201020e-02
# fd approx = 3.071824494567e-01
# fprime_p  = 3.071824423905e-01
# |diff|    = 7.066e-09
# rel diff  = 7.066e-09
# [p=0.450, s=0.10, d=3, r=1.0, eps=1.00] |diff|=7.066e-09, rel=7.066e-09
# === Check f'(p) vs finite difference ===
# p         = 0.7200000000000001
# s         = 0.1
# d         = 3
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.058824535873e-01
# f(p-h)    = 2.056465277925e-01
# fd approx = 1.179628974063e+00
# fprime_p  = 1.179628832916e+00
# |diff|    = 1.411e-07
# rel diff  = 1.197e-07
# [p=0.720, s=0.10, d=3, r=1.0, eps=1.00] |diff|=1.411e-07, rel=1.197e-07
# === Check f'(p) vs finite difference ===
# p         = 0.09000000000000001
# s         = 0.1
# d         = 3
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.261121877651e-02
# f(p-h)    = 3.253627177844e-02
# fd approx = 3.747349903722e-01
# fprime_p  = 3.747350052575e-01
# |diff|    = 1.489e-08
# rel diff  = 1.489e-08
# [p=0.090, s=0.10, d=3, r=2.0, eps=0.10] |diff|=1.489e-08, rel=1.489e-08
# === Check f'(p) vs finite difference ===
# p         = 0.27
# s         = 0.1
# d         = 3
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.035194790349e-01
# f(p-h)    = 1.034343839348e-01
# fd approx = 4.254755002004e-01
# fprime_p  = 4.254754946344e-01
# |diff|    = 5.566e-09
# rel diff  = 5.566e-09
# [p=0.270, s=0.10, d=3, r=2.0, eps=0.10] |diff|=5.566e-09, rel=5.566e-09
# === Check f'(p) vs finite difference ===
# p         = 0.45
# s         = 0.1
# d         = 3
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 1.923034789806e-01
# f(p-h)    = 1.921866955176e-01
# fd approx = 5.839173148596e-01
# fprime_p  = 5.839173044666e-01
# |diff|    = 1.039e-08
# rel diff  = 1.039e-08
# [p=0.450, s=0.10, d=3, r=2.0, eps=0.10] |diff|=1.039e-08, rel=1.039e-08
# === Check f'(p) vs finite difference ===
# p         = 0.7200000000000001
# s         = 0.1
# d         = 3
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 4.359981760918e-01
# f(p-h)    = 4.356987488902e-01
# fd approx = 1.497136007728e+00
# ...
# rel diff  = 5.586e-08
# [p=0.560, s=0.30, d=5, r=5.0, eps=0.50] |diff|=1.202e-07, rel=5.586e-08
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 5
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 1.148778716174e-03
# f(p-h)    = 1.129516335457e-03
# fd approx = 9.631190358378e-02
# fprime_p  = 9.631169464628e-02
# |diff|    = 2.089e-07
# rel diff  = 2.089e-07
# [p=0.070, s=0.30, d=5, r=5.0, eps=1.00] |diff|=2.089e-07, rel=2.089e-07
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 5
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 8.143033679640e-02
# f(p-h)    = 8.123083162049e-02
# fd approx = 9.975258795576e-01
# fprime_p  = 9.975259097757e-01
# |diff|    = 3.022e-08
# rel diff  = 3.022e-08
# [p=0.210, s=0.30, d=5, r=5.0, eps=1.00] |diff|=3.022e-08, rel=3.022e-08
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 5
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.645318348998e-01
# f(p-h)    = 2.642099405286e-01
# fd approx = 1.609471855608e+00
# fprime_p  = 1.609471844080e+00
# |diff|    = 1.153e-08
# rel diff  = 7.163e-09
# [p=0.350, s=0.30, d=5, r=5.0, eps=1.00] |diff|=1.153e-08, rel=7.163e-09
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 5
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 7.129508773295e-01
# f(p-h)    = 7.124171217995e-01
# fd approx = 2.668777649720e+00
# fprime_p  = 2.668777785197e+00
# |diff|    = 1.355e-07
# rel diff  = 5.076e-08
# [p=0.560, s=0.30, d=5, r=5.0, eps=1.00] |diff|=1.355e-07, rel=5.076e-08
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 2.932810420775e-01
# f(p-h)    = 2.931914466629e-01
# fd approx = 4.479770731541e-01
# fprime_p  = 4.479770681571e-01
# |diff|    = 4.997e-09
# rel diff  = 4.997e-09
# [p=0.070, s=0.30, d=10, r=1.0, eps=0.10] |diff|=4.997e-09, rel=4.997e-09
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.704453797596e-01
# f(p-h)    = 3.703118664215e-01
# fd approx = 6.675666907791e-01
# fprime_p  = 6.675666807709e-01
# |diff|    = 1.001e-08
# rel diff  = 1.001e-08
# [p=0.210, s=0.30, d=10, r=1.0, eps=0.10] |diff|=1.001e-08, rel=1.001e-08
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 4.859299545760e-01
# f(p-h)    = 4.857276905693e-01
# fd approx = 1.011320033683e+00
# fprime_p  = 1.011320012217e+00
# |diff|    = 2.147e-08
# rel diff  = 2.123e-08
# [p=0.350, s=0.30, d=10, r=1.0, eps=0.10] |diff|=2.147e-08, rel=2.123e-08
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 7.908077486470e-01
# f(p-h)    = 7.904141348007e-01
# fd approx = 1.968069231679e+00
# fprime_p  = 1.968069336218e+00
# |diff|    = 1.045e-07
# rel diff  = 5.312e-08
# [p=0.560, s=0.30, d=10, r=1.0, eps=0.10] |diff|=1.045e-07, rel=5.312e-08
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.507122516024e-01
# f(p-h)    = 1.506199448990e-01
# fd approx = 4.615335170363e-01
# fprime_p  = 4.615335092338e-01
# |diff|    = 7.803e-09
# rel diff  = 7.803e-09
# [p=0.070, s=0.30, d=10, r=1.0, eps=0.50] |diff|=7.803e-09, rel=7.803e-09
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.341308108357e-01
# f(p-h)    = 2.339813065838e-01
# fd approx = 7.475212593321e-01
# fprime_p  = 7.475212472133e-01
# |diff|    = 1.212e-08
# rel diff  = 1.212e-08
# [p=0.210, s=0.30, d=10, r=1.0, eps=0.50] |diff|=1.212e-08, rel=1.212e-08
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 3.670650319685e-01
# f(p-h)    = 3.668275423135e-01
# fd approx = 1.187448275277e+00
# fprime_p  = 1.187448247914e+00
# |diff|    = 2.736e-08
# rel diff  = 2.304e-08
# [p=0.350, s=0.30, d=10, r=1.0, eps=0.50] |diff|=2.736e-08, rel=2.304e-08
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 7.355405100940e-01
# f(p-h)    = 7.350533011516e-01
# fd approx = 2.436044712097e+00
# fprime_p  = 2.436044830693e+00
# |diff|    = 1.186e-07
# rel diff  = 4.868e-08
# [p=0.560, s=0.30, d=10, r=1.0, eps=0.50] |diff|=1.186e-07, rel=4.868e-08
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 3.429558920390e-02
# f(p-h)    = 3.424230826104e-02
# fd approx = 2.664047143073e-01
# fprime_p  = 2.664046973884e-01
# |diff|    = 1.692e-08
# rel diff  = 1.692e-08
# [p=0.070, s=0.30, d=10, r=1.0, eps=1.00] |diff|=1.692e-08, rel=1.692e-08
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 9.474557112645e-02
# f(p-h)    = 9.461918472864e-02
# fd approx = 6.319319890657e-01
# fprime_p  = 6.319319696804e-01
# |diff|    = 1.939e-08
# rel diff  = 1.939e-08
# [p=0.210, s=0.30, d=10, r=1.0, eps=1.00] |diff|=1.939e-08, rel=1.939e-08
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.225235917545e-01
# f(p-h)    = 2.222746945221e-01
# fd approx = 1.244486161885e+00
# fprime_p  = 1.244486123276e+00
# |diff|    = 3.861e-08
# rel diff  = 3.102e-08
# [p=0.350, s=0.30, d=10, r=1.0, eps=1.00] |diff|=3.861e-08, rel=3.102e-08
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 10
# r         = 1.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 6.532596615179e-01
# f(p-h)    = 6.526480508522e-01
# fd approx = 3.058053328535e+00
# fprime_p  = 3.058053455494e+00
# |diff|    = 1.270e-07
# rel diff  = 4.152e-08
# [p=0.560, s=0.30, d=10, r=1.0, eps=1.00] |diff|=1.270e-07, rel=4.152e-08
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 2.995215667487e-01
# f(p-h)    = 2.994134874270e-01
# fd approx = 5.403966084430e-01
# fprime_p  = 5.403966052928e-01
# |diff|    = 3.150e-09
# rel diff  = 3.150e-09
# [p=0.070, s=0.30, d=10, r=2.0, eps=0.10] |diff|=3.150e-09, rel=3.150e-09
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.898655579606e-01
# f(p-h)    = 3.897134504192e-01
# fd approx = 7.605377073483e-01
# fprime_p  = 7.605376986011e-01
# |diff|    = 8.747e-09
# rel diff  = 8.747e-09
# [p=0.210, s=0.30, d=10, r=2.0, eps=0.10] |diff|=8.747e-09, rel=8.747e-09
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 5.174003963395e-01
# f(p-h)    = 5.171831585009e-01
# fd approx = 1.086189193020e+00
# fprime_p  = 1.086189175981e+00
# |diff|    = 1.704e-08
# rel diff  = 1.569e-08
# [p=0.350, s=0.30, d=10, r=2.0, eps=0.10] |diff|=1.704e-08, rel=1.569e-08
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 8.240260443554e-01
# f(p-h)    = 8.236587993904e-01
# fd approx = 1.836224825261e+00
# fprime_p  = 1.836224967530e+00
# |diff|    = 1.423e-07
# rel diff  = 7.748e-08
# [p=0.560, s=0.30, d=10, r=2.0, eps=0.10] |diff|=1.423e-07, rel=7.748e-08
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.573380607328e-01
# f(p-h)    = 1.572246991415e-01
# fd approx = 5.668079563199e-01
# fprime_p  = 5.668079514739e-01
# |diff|    = 4.846e-09
# rel diff  = 4.846e-09
# [p=0.070, s=0.30, d=10, r=2.0, eps=0.50] |diff|=4.846e-09, rel=4.846e-09
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 2.572454989502e-01
# f(p-h)    = 2.570712997183e-01
# fd approx = 8.709961596909e-01
# fprime_p  = 8.709961505782e-01
# |diff|    = 9.113e-09
# rel diff  = 9.113e-09
# [p=0.210, s=0.30, d=10, r=2.0, eps=0.50] |diff|=9.113e-09, rel=9.113e-09
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 4.065064985984e-01
# f(p-h)    = 4.062484709670e-01
# fd approx = 1.290138157066e+00
# fprime_p  = 1.290138135752e+00
# |diff|    = 2.131e-08
# rel diff  = 1.652e-08
# [p=0.350, s=0.30, d=10, r=2.0, eps=0.50] |diff|=2.131e-08, rel=1.652e-08
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 7.782707369533e-01
# f(p-h)    = 7.778166730944e-01
# fd approx = 2.270319294399e+00
# fprime_p  = 2.270319461845e+00
# |diff|    = 1.674e-07
# rel diff  = 7.375e-08
# [p=0.560, s=0.30, d=10, r=2.0, eps=0.50] |diff|=1.674e-07, rel=7.375e-08
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 3.834069006807e-02
# f(p-h)    = 3.827134248700e-02
# fd approx = 3.467379053452e-01
# fprime_p  = 3.467378867040e-01
# |diff|    = 1.864e-08
# rel diff  = 1.864e-08
# [p=0.070, s=0.30, d=10, r=2.0, eps=1.00] |diff|=1.864e-08, rel=1.864e-08
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 1.163706097835e-01
# f(p-h)    = 1.162118531800e-01
# fd approx = 7.937830175551e-01
# fprime_p  = 7.937830055556e-01
# |diff|    = 1.200e-08
# rel diff  = 1.200e-08
# [p=0.210, s=0.30, d=10, r=2.0, eps=1.00] |diff|=1.200e-08, rel=1.200e-08
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 2.680890890667e-01
# f(p-h)    = 2.678071889324e-01
# fd approx = 1.409500671720e+00
# fprime_p  = 1.409500643255e+00
# |diff|    = 2.847e-08
# rel diff  = 2.020e-08
# [p=0.350, s=0.30, d=10, r=2.0, eps=1.00] |diff|=2.847e-08, rel=2.020e-08
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 10
# r         = 2.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 7.098107304943e-01
# f(p-h)    = 7.092381826470e-01
# fd approx = 2.862739236528e+00
# fprime_p  = 2.862739433669e+00
# |diff|    = 1.971e-07
# rel diff  = 6.886e-08
# [p=0.560, s=0.30, d=10, r=2.0, eps=1.00] |diff|=1.971e-07, rel=6.886e-08
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 3.174956313326e-01
# f(p-h)    = 3.173365408319e-01
# fd approx = 7.954525030790e-01
# fprime_p  = 7.954525048979e-01
# |diff|    = 1.819e-09
# rel diff  = 1.819e-09
# [p=0.070, s=0.30, d=10, r=5.0, eps=0.10] |diff|=1.819e-09, rel=1.819e-09
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 4.414442756041e-01
# f(p-h)    = 4.412480217718e-01
# fd approx = 9.812691618188e-01
# fprime_p  = 9.812691554845e-01
# |diff|    = 6.334e-09
# rel diff  = 6.334e-09
# [p=0.210, s=0.30, d=10, r=5.0, eps=0.10] |diff|=6.334e-09, rel=6.334e-09
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 5.955364026028e-01
# f(p-h)    = 5.952898165426e-01
# fd approx = 1.232930301023e+00
# fprime_p  = 1.232930296565e+00
# |diff|    = 4.458e-09
# rel diff  = 3.616e-09
# [p=0.350, s=0.30, d=10, r=5.0, eps=0.10] |diff|=4.458e-09, rel=3.616e-09
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 0.1
# h_eff     = 1.000000e-04
# f(p+h)    = 8.927609471273e-01
# f(p-h)    = 8.924720487035e-01
# fd approx = 1.444492118863e+00
# fprime_p  = 1.444492297834e+00
# |diff|    = 1.790e-07
# rel diff  = 1.239e-07
# [p=0.560, s=0.30, d=10, r=5.0, eps=0.10] |diff|=1.790e-07, rel=1.239e-07
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 1.767402530675e-01
# f(p-h)    = 1.765673471769e-01
# fd approx = 8.645294533305e-01
# fprime_p  = 8.645294633968e-01
# |diff|    = 1.007e-08
# rel diff  = 1.007e-08
# [p=0.070, s=0.30, d=10, r=5.0, eps=0.50] |diff|=1.007e-08, rel=1.007e-08
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 3.188824521837e-01
# f(p-h)    = 3.186504964533e-01
# fd approx = 1.159778652066e+00
# fprime_p  = 1.159778648118e+00
# |diff|    = 3.948e-09
# rel diff  = 3.404e-09
# [p=0.210, s=0.30, d=10, r=5.0, eps=0.50] |diff|=3.948e-09, rel=3.404e-09
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 5.033038693466e-01
# f(p-h)    = 5.030064081099e-01
# fd approx = 1.487306183651e+00
# fprime_p  = 1.487306178244e+00
# |diff|    = 5.407e-09
# rel diff  = 3.636e-09
# [p=0.350, s=0.30, d=10, r=5.0, eps=0.50] |diff|=5.407e-09, rel=3.636e-09
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 0.5
# h_eff     = 1.000000e-04
# f(p+h)    = 8.656061517924e-01
# f(p-h)    = 8.652491372761e-01
# fd approx = 1.785072581387e+00
# fprime_p  = 1.785072799480e+00
# |diff|    = 2.181e-07
# rel diff  = 1.222e-07
# [p=0.560, s=0.30, d=10, r=5.0, eps=0.50] |diff|=2.181e-07, rel=1.222e-07
# === Check f'(p) vs finite difference ===
# p         = 0.06999999999999999
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 5.121814260454e-02
# f(p-h)    = 5.109754094416e-02
# fd approx = 6.030083018656e-01
# fprime_p  = 6.030082993216e-01
# |diff|    = 2.544e-09
# rel diff  = 2.544e-09
# [p=0.070, s=0.30, d=10, r=5.0, eps=1.00] |diff|=2.544e-09, rel=2.544e-09
# === Check f'(p) vs finite difference ===
# p         = 0.21
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 1.781593408052e-01
# f(p-h)    = 1.779213456559e-01
# fd approx = 1.189975746873e+00
# fprime_p  = 1.189975751432e+00
# |diff|    = 4.560e-09
# rel diff  = 3.832e-09
# [p=0.210, s=0.30, d=10, r=5.0, eps=1.00] |diff|=4.560e-09, rel=3.832e-09
# === Check f'(p) vs finite difference ===
# p         = 0.35
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 3.820684941309e-01
# f(p-h)    = 3.817229400353e-01
# fd approx = 1.727770477741e+00
# fprime_p  = 1.727770472610e+00
# |diff|    = 5.131e-09
# rel diff  = 2.970e-09
# [p=0.350, s=0.30, d=10, r=5.0, eps=1.00] |diff|=5.131e-09, rel=2.970e-09
# === Check f'(p) vs finite difference ===
# p         = 0.5599999999999999
# s         = 0.3
# d         = 10
# r         = 5.0
# eps       = 1.0
# h_eff     = 1.000000e-04
# f(p+h)    = 8.244703805041e-01
# f(p-h)    = 8.240157548860e-01
# fd approx = 2.273128090156e+00
# fprime_p  = 2.273128367504e+00
# |diff|    = 2.773e-07
# rel diff  = 1.220e-07
# [p=0.560, s=0.30, d=10, r=5.0, eps=1.00] |diff|=2.773e-07, rel=1.220e-07
#
# === Sweep summary ===
# max |diff|  = 2.773e-07
# max rel diff = 1.220e-07
# worst at p=0.5599999999999999, s=0.3, d=10, r=5.0, eps=1.0
