# %%
import numpy as np
import os
import sys


# Navigate to the parent directory of the project structure
project_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
src_dir = os.path.join(project_dir, 'src')
log_dir = os.path.join(project_dir, 'log')
fig_dir = os.path.join(project_dir, 'fig')

# Add the src directory to sys.path
sys.path.append(src_dir)

from accounting.Gaussian_shifted_mean import delta_via_dp_accounting, delta_gaussian_shift_closed_form, delta_via_fft_accounting

# %%
# example:
eps = 1.0; sigma = 16; k = 100
print(delta_via_dp_accounting(eps, sigma, k))
# Out:
# 0.0231035362143645

# %%
delta_gaussian_shift_closed_form(eps, sigma, k)
# Out:
# 0.023103536214362425

# %%
delta_via_fft_accounting(eps, sigma, k)
# Out:
# 0.023103500468258015
